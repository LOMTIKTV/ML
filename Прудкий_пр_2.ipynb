# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

url = "https://uk.wikipedia.org/wiki/%D0%A1%D0%B5%D1%80%D0%B5%D0%B4%D0%BD%D1%8F_%D0%B7%D0%B0%D1%80%D0%BE%D0%B1%D1%96%D1%82%D0%BD%D0%B0_%D0%BF%D0%BB%D0%B0%D1%82%D0%B0_%D0%B2_%D0%A3%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D1%96"

data = pd.read_html(url, header=0)[2]

# %% [markdown]
# 1.	Виведіть перші 5 рядків таблиці.

# %%
df_1 = data.head(5)
print(df_1)
# Out:
#     Рік В національній валюті В доларах США
# 0  1992              5832,88▲        28,04▼  \
# 1  1993               163533▲        36,03▲
# 2  1994              1426343▲        44,99▲
# 3  1995              7304000▲        49,53▲
# 4  1996               125,23▼        68,45▲
#
#   Кількість кг хліба[20] на середню зарплату
# 0                                   1015,67▲  \
# 1                                    430,42▼
# 2                                    372,76▼
# 3                                    201,76▼
# 4                                    198,62▼
#
#   Кількість БігМаків на середню зарплату
# 0                                      —
# 1                                      —
# 2                                      —
# 3                                      —
# 4                                      —

# %% [markdown]
# 2.	Визначте кількість рядків і стовпчиків за допомогою атрибуту shape

# %%
num_rows, num_columns = data.shape
print(f"Кількість рядків: {num_rows}, Кількість стовпчиків: {num_columns}")
# Out:
# Кількість рядків: 32, Кількість стовпчиків: 5

# %% [markdown]
# 3.	Визначте загальну кількість років та кількість місяців у даних.

# %%
num_years = len(data['Рік']) - 1 
num_months = num_years * 12  
print("Загальна кількість років =", num_years)
print("Загальна кількість місяців =", num_months)
# Out:
# Загальна кількість років = 31
# Загальна кількість місяців = 372

# %% [markdown]
# 4.	Замінити пропущені значення  «-» в таблиці на NaN

# %%
data = data.rename(columns={
    "Рік": "Year",
    "В національній валюті": "Salary in UAH",
    "В доларах США": "Salary in USD",
    "Кількість кг хліба[20] на середню зарплату": "Bread per Salary",
    "Кількість БігМаків на середню зарплату": "BigMacs per Salary"
})
data = data.replace("—", np.nan)
data
# Out:
#      Year Salary in UAH Salary in USD Bread per Salary BigMacs per Salary
# 0    1992      5832,88▲        28,04▼         1015,67▲                NaN
# 1    1993       163533▲        36,03▲          430,42▼                NaN
# 2    1994      1426343▲        44,99▲          372,76▼                NaN
# 3    1995      7304000▲        49,53▲          201,76▼                NaN
# 4    1996       125,23▼        68,45▲          198,62▼                NaN
# 5    1997       143,09▲        76,86▲          211,13▲             20[21]
# 6    1998       152,83▲        62,39▼          177,69▼               н.д.
# 7    1999       177,39▲        42,95▼          180,68▲            24▲[22]
# 8    2000       231,04▲        42,47▼          117,51▼               н.д.
# 9    2001       311,62▲        58,01▲          153,57▲            50▲[23]
# 10   2002       375,98▲        70,59▲          213,84▲               н.д.
# 11   2003       462,58▲        86,74▲          276,27▲               н.д.
# 12   2004       590,53▲       111,02▲          276,06▼                81▲
# 13   2005       806,14▲       157,30▲          332,05▲               111▲
# 14   2006      1042,88▲       206,51▲          441,28▲               123▲
# 15   2007      1352,75▲       267,87▲          498,66▲               146▲
# 16   2008      1808,92▲       343,43▲          585,00▲               164▲
# 17   2009      1909,25▲       245,05▼          497,02▼               136▼
# 18   2010      2246,75▲       283,12▲          527,82▲               155▲
# 19   2011      2639,17▲       331,24▲          564,37▲               160▲
# 20   2012      3031,92▲       379,42▲          585,38▲               202▲
# 21   2013      3273,82▲       409,59▲          625,00▲               172▼
# 22   2014      3474,75▲       292,32▼          642,39▲               182▲
# 23   2015      4207,33▲       162,60▼          517,22▼               124▼
# 24   2016      5187,33▲       203,02▲          441,05▼               133▲
# 25   2017      7105,42▲       267,16▲          450,35▲               161▲
# 26   2018      8867,33▲       325,99▲          497,05▲               177▲
# 27   2019     10503,75▲       406,40▲          528,09▲               184▲
# 28   2020     11596,60▲       430,21▲          549,08▲               187▲
# 29   2021     14017,80▲       514,41▲          560,03▲               216▲
# 30  2022*     13376,21▼       380,00▼          409,57▼               132▼
# 31  2023*     12954,12▼       327,70▼          367,85▼               123▼

# %% [markdown]
# 5.	Визначити тип стовпців за допомогою dtypes.

# %%
data.dtypes
# Out:
# Year                  object
# Salary in UAH         object
# Salary in USD         object
# Bread per Salary      object
# BigMacs per Salary    object
# dtype: object

# %% [markdown]
# 6.	Видаліть передостанній і останній стовпчики ( Кількість кгхліба[20] на середнюзарплату,  Кільксть БігМаків на середню зарплату). Далі працюйте з оновленою таблицею.

# %%
data = data.drop(columns=["Bread per Salary", "BigMacs per Salary"])
data
# Out:
#      Year Salary in UAH Salary in USD
# 0    1992      5832,88▲        28,04▼
# 1    1993       163533▲        36,03▲
# 2    1994      1426343▲        44,99▲
# 3    1995      7304000▲        49,53▲
# 4    1996       125,23▼        68,45▲
# 5    1997       143,09▲        76,86▲
# 6    1998       152,83▲        62,39▼
# 7    1999       177,39▲        42,95▼
# 8    2000       231,04▲        42,47▼
# 9    2001       311,62▲        58,01▲
# 10   2002       375,98▲        70,59▲
# 11   2003       462,58▲        86,74▲
# 12   2004       590,53▲       111,02▲
# 13   2005       806,14▲       157,30▲
# 14   2006      1042,88▲       206,51▲
# 15   2007      1352,75▲       267,87▲
# 16   2008      1808,92▲       343,43▲
# 17   2009      1909,25▲       245,05▼
# 18   2010      2246,75▲       283,12▲
# 19   2011      2639,17▲       331,24▲
# 20   2012      3031,92▲       379,42▲
# 21   2013      3273,82▲       409,59▲
# 22   2014      3474,75▲       292,32▼
# 23   2015      4207,33▲       162,60▼
# 24   2016      5187,33▲       203,02▲
# 25   2017      7105,42▲       267,16▲
# 26   2018      8867,33▲       325,99▲
# 27   2019     10503,75▲       406,40▲
# 28   2020     11596,60▲       430,21▲
# 29   2021     14017,80▲       514,41▲
# 30  2022*     13376,21▼       380,00▼
# 31  2023*     12954,12▼       327,70▼

# %%
data["Salary in UAH"] = data["Salary in UAH"].str.replace('▲', "").str.replace('▼', "")
data["Salary in USD"] = data["Salary in USD"].str.replace('▲', "").str.replace('▼', "")

# %% [markdown]
# 7.	Замінити тип нечислових даних на числові.

# %%
data.dtypes
# Out:
# Year             object
# Salary in UAH    object
# Salary in USD    object
# dtype: object

# %%
data['Salary in UAH'] = data['Salary in UAH'].str.replace(',', '.').astype(float)
data['Salary in USD'] = data['Salary in USD'].str.replace(',', '.').astype(float)
data
# Out:
#      Year  Salary in UAH  Salary in USD
# 0    1992        5832.88          28.04
# 1    1993      163533.00          36.03
# 2    1994     1426343.00          44.99
# 3    1995     7304000.00          49.53
# 4    1996         125.23          68.45
# 5    1997         143.09          76.86
# 6    1998         152.83          62.39
# 7    1999         177.39          42.95
# 8    2000         231.04          42.47
# 9    2001         311.62          58.01
# 10   2002         375.98          70.59
# 11   2003         462.58          86.74
# 12   2004         590.53         111.02
# 13   2005         806.14         157.30
# 14   2006        1042.88         206.51
# 15   2007        1352.75         267.87
# 16   2008        1808.92         343.43
# 17   2009        1909.25         245.05
# 18   2010        2246.75         283.12
# 19   2011        2639.17         331.24
# 20   2012        3031.92         379.42
# 21   2013        3273.82         409.59
# 22   2014        3474.75         292.32
# 23   2015        4207.33         162.60
# 24   2016        5187.33         203.02
# 25   2017        7105.42         267.16
# 26   2018        8867.33         325.99
# 27   2019       10503.75         406.40
# 28   2020       11596.60         430.21
# 29   2021       14017.80         514.41
# 30  2022*       13376.21         380.00
# 31  2023*       12954.12         327.70

# %%
data.dtypes
# Out:
# Year              object
# Salary in UAH    float64
# Salary in USD    float64
# dtype: object

# %% [markdown]
# 8.	Порахуйте частку пропусків в кожній колонці (за допомогою методів isnull , sum, len)

# %%
data_pass = data.isnull().sum() / len(data)
data_pass
# Out:
# Year             0.0
# Salary in UAH    0.0
# Salary in USD    0.0
# dtype: float64

# %% [markdown]
# 9.	Замініть всі пропущені значення на середні значення по (стовпцю).

# %%
#-

# %% [markdown]
# 10.	Знайдіть рік з найвищою зарплатою в Україні в грн і вкажіть цю зарплату.

# %%
salary_year = data[data['Salary in UAH'] == data['Salary in UAH'].max()]['Year'].values[0]
salary_amount = data['Salary in UAH'].max()

print("Рік з найвищою зарплатою:", salary_year)
print("Найвища зарплата в Україні в грн:", salary_amount)
# Out:
# Рік з найвищою зарплатою: 1995
# Найвища зарплата в Україні в грн: 7304000.0

# %% [markdown]
# 11.	Знайдіть рік з мінімальною  зарплатою в Україні в дол. США і вкажіть цю зарплату.

# %%
salary_year = data[data['Salary in USD'] == data['Salary in USD'].min()]['Year'].values[0]
salary_amount = data['Salary in USD'].min()

print("Рік з найменшою зарплатою:", salary_year)
print("Найменша зарплата в Україні в дол.США:", salary_amount)
# Out:
# Рік з найменшою зарплатою: 1992
# Найменша зарплата в Україні в дол.США: 28.04

# %% [markdown]
# 12.	Виведіть роки, коли зарплата в грн була вище середньої.

# %%
salary_above_average = data[data["Salary in UAH"] > data["Salary in UAH"].mean()]["Year"]
print(salary_above_average.tolist())
# Out:
# ['1994', '1995']

# %% [markdown]
# 13.	Порівняйте  зарплату  в грн за останні два доступних роки.

# %%
last_two_years_salary = data.iloc[-2:]["Salary in UAH"]
print(last_two_years_salary)
data
# Out:
# 30    13376.21
# 31    12954.12
# Name: Salary in UAH, dtype: float64
#      Year  Salary in UAH  Salary in USD
# 0    1992        5832.88          28.04
# 1    1993      163533.00          36.03
# 2    1994     1426343.00          44.99
# 3    1995     7304000.00          49.53
# 4    1996         125.23          68.45
# 5    1997         143.09          76.86
# 6    1998         152.83          62.39
# 7    1999         177.39          42.95
# 8    2000         231.04          42.47
# 9    2001         311.62          58.01
# 10   2002         375.98          70.59
# 11   2003         462.58          86.74
# 12   2004         590.53         111.02
# 13   2005         806.14         157.30
# 14   2006        1042.88         206.51
# 15   2007        1352.75         267.87
# 16   2008        1808.92         343.43
# 17   2009        1909.25         245.05
# 18   2010        2246.75         283.12
# 19   2011        2639.17         331.24
# 20   2012        3031.92         379.42
# 21   2013        3273.82         409.59
# 22   2014        3474.75         292.32
# 23   2015        4207.33         162.60
# 24   2016        5187.33         203.02
# 25   2017        7105.42         267.16
# 26   2018        8867.33         325.99
# 27   2019       10503.75         406.40
# 28   2020       11596.60         430.21
# 29   2021       14017.80         514.41
# 30  2022*       13376.21         380.00
# 31  2023*       12954.12         327.70

# %% [markdown]
# 14.	Створіть графік, що відображає  зарплату в Україні з часом (за роками).

# %%
plt.figure(figsize=(25, 6))
plt.plot(data["Year"], data["Salary in USD"], marker='o')
plt.title("Середня зарплата в Україні за роками")
plt.xlabel("Рік")
plt.ylabel("Середня зарплата в дол.США")
plt.grid(True)
plt.show()

# %% [markdown]
# 15.	Видаліть останній рік з таблиці та виведіть оновлену таблицю.

# %%
data = data.iloc[:-1]
data
# Out:
#      Year  Salary in UAH  Salary in USD
# 0    1992        5832.88          28.04
# 1    1993      163533.00          36.03
# 2    1994     1426343.00          44.99
# 3    1995     7304000.00          49.53
# 4    1996         125.23          68.45
# 5    1997         143.09          76.86
# 6    1998         152.83          62.39
# 7    1999         177.39          42.95
# 8    2000         231.04          42.47
# 9    2001         311.62          58.01
# 10   2002         375.98          70.59
# 11   2003         462.58          86.74
# 12   2004         590.53         111.02
# 13   2005         806.14         157.30
# 14   2006        1042.88         206.51
# 15   2007        1352.75         267.87
# 16   2008        1808.92         343.43
# 17   2009        1909.25         245.05
# 18   2010        2246.75         283.12
# 19   2011        2639.17         331.24
# 20   2012        3031.92         379.42
# 21   2013        3273.82         409.59
# 22   2014        3474.75         292.32
# 23   2015        4207.33         162.60
# 24   2016        5187.33         203.02
# 25   2017        7105.42         267.16
# 26   2018        8867.33         325.99
# 27   2019       10503.75         406.40
# 28   2020       11596.60         430.21
# 29   2021       14017.80         514.41
# 30  2022*       13376.21         380.00

# %% [markdown]
# 16.	Побудуйте графік, що відображає середню зарплату в Україні в розрізі років без останнього року.

# %%
plt.figure(figsize=(25, 6))
plt.plot(data["Year"], data["Salary in USD"], marker='o')
plt.title("Середня зарплата в Україні за роками (без останнього року)")
plt.xlabel("Рік")
plt.ylabel("Середня зарплата в дол.США")
plt.grid(True)
plt.show()

# %% [markdown]
# 17.	Обчисліть зарплату за останні два роки і порівняйте її із зарплатою за останні 5 років. Вкажіть, чи є різниця, і в якому напрямку.

# %%
two_years = data.iloc[-2:]["Salary in USD"].sum()
five_years = data.iloc[-5:]["Salary in USD"].sum()

if two_years > five_years:
    print("Зарплата за останні два роки більше за зарплату за останні 5 років.")
else:
    print("Зарплата за останні два роки менше за зарплату за останні 5 років.")
# Out:
# Зарплата за останні два роки менше за зарплату за останні 5 років.

# %% [markdown]
# В практичній роботі були використані бібліотеки pandas, numpy та matplotlib.pyplot. За допомогою цих бібліотек  в практичній роботі читали таблицю з сайту, редактували її, видаляли рядки та створювали графік на основі данних з прочитаної таблиці.
